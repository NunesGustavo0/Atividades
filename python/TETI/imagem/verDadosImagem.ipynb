# %%
path_img = 'D:/Salve_Aqui_Seus_Arquivos/Teti2024/teti_imagens/'

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image, ImageOps
# %matplotlib inline

# %%
from pylab import *

# %%
im1 = array(Image.open(path_img + 'Pelicanos_mar.jpg'))

# %%
im1
# Out:
# array([[[243, 220, 108],
#         [243, 220, 108],
#         [244, 221, 109],
#         ...,
#         [245, 221,  99],
#         [246, 222, 100],
#         [246, 222, 100]],
#
#        [[243, 220, 108],
#         [243, 220, 108],
#         [243, 220, 108],
#         ...,
#         [243, 219,  97],
#         [245, 221,  99],
#         [245, 221,  99]],
#
#        [[243, 220, 108],
#         [243, 220, 108],
#         [242, 219, 107],
#         ...,
#         [242, 216,  95],
#         [244, 220,  98],
#         [244, 220,  98]],
#
#        ...,
#
#        [[142, 118,  80],
#         [141, 117,  79],
#         [136, 114,  75],
#         ...,
#         [132, 130, 115],
#         [131, 129, 114],
#         [131, 129, 114]],
#
#        [[147, 123,  85],
#         [142, 120,  81],
#         [136, 114,  75],
#         ...,
#         [133, 130, 113],
#         [133, 131, 116],
#         [133, 131, 116]],
#
#        [[148, 126,  87],
#         [141, 122,  82],
#         [134, 114,  77],
#         ...,
#         [133, 130, 113],
#         [133, 130, 115],
#         [133, 130, 115]]], dtype=uint8)

# %%
im1.shape
# Out:
# (765, 1322, 3)

# %%
def plot_2img(im1, tit1, im2, tit2, tam):
    figure(figsize = tam)
    plt.subplot(1, 2, 1), plt.imshow(im1), plt.title(tit1)
    plt.xticks([]), plt.yticks([])
    plt.subplot(1, 2, 2), plt.imshow(im2), plt.title(tit2)
    plt.xticks([]), plt.yticks([])
    plt.show

# %%
plot_2img(im1, 'Imagem1', im1, 'Imagem2', (12, 10))

# %%
def plot_2img(im1, tit1, im2, tit2, im3, tit3, tam):
    figure(figsize = tam)
    plt.subplot(1, 3, 1), plt.imshow(im1), plt.title(tit1)
    plt.xticks([]), plt.yticks([])
    plt.subplot(1, 3, 2), plt.imshow(im2), plt.title(tit2)
    plt.xticks([]), plt.yticks([])
    plt.subplot(1, 3, 3), plt.imshow(im3), plt.title(tit3)
    plt.xticks([]), plt.yticks([])
    plt.show

# %%
plot_2img(im1, 'Imagem1', im1, 'Imagem2', im1, 'Imagem3', (12, 10))

# %%
im1.shape
# Out:
# (765, 1322, 3)

# %%
im1_ = im1.ravel()

# %%
im1_
# Out:
# array([243, 220, 108, ..., 133, 130, 115], dtype=uint8)

# %%
im1_.shape
# Out:
# (3033990,)

# %%
plt.hist(im1_)
# Out:
# (array([ 15488.,  37299., 175741., 582832., 329257., 231566., 167591.,
#         186635., 595867., 711714.]),
#  array([  0. ,  25.5,  51. ,  76.5, 102. , 127.5, 153. , 178.5, 204. ,
#         229.5, 255. ]),
#  <BarContainer object of 10 artists>)

# %%
np.save('saida_img', im1)

# %%
pwd
# Out:
# 'D:\\Salve_Aqui_Seus_Arquivos\\Teti2024'

# %%
im4 = np.load('saida_img.npy')

# %%
im4
# Out:
# array([[[243, 220, 108],
#         [243, 220, 108],
#         [244, 221, 109],
#         ...,
#         [245, 221,  99],
#         [246, 222, 100],
#         [246, 222, 100]],
#
#        [[243, 220, 108],
#         [243, 220, 108],
#         [243, 220, 108],
#         ...,
#         [243, 219,  97],
#         [245, 221,  99],
#         [245, 221,  99]],
#
#        [[243, 220, 108],
#         [243, 220, 108],
#         [242, 219, 107],
#         ...,
#         [242, 216,  95],
#         [244, 220,  98],
#         [244, 220,  98]],
#
#        ...,
#
#        [[142, 118,  80],
#         [141, 117,  79],
#         [136, 114,  75],
#         ...,
#         [132, 130, 115],
#         [131, 129, 114],
#         [131, 129, 114]],
#
#        [[147, 123,  85],
#         [142, 120,  81],
#         [136, 114,  75],
#         ...,
#         [133, 130, 113],
#         [133, 131, 116],
#         [133, 131, 116]],
#
#        [[148, 126,  87],
#         [141, 122,  82],
#         [134, 114,  77],
#         ...,
#         [133, 130, 113],
#         [133, 130, 115],
#         [133, 130, 115]]], dtype=uint8)

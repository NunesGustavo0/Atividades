# %%
path_img = 'D:/Salve_Aqui_Seus_Arquivos/Teti2024/teti_imagens/'

# %%
import numpy as np
import matplotlib as plt
from PIL import Image, ImageOps
# %matplotlib inline

# %%
from pylab import *

# %%
im1 = array(Image.open(path_img + 'cheetah.jpg'))

# %%
def plot_3img(im1, tit1, im2, tit2, tam):
    figure(figsize = tam)
    plt.subplot(1,2,1), plt.imshow(im1), plt.title(tit1)
    plt.xticks([]), plt.yticks([])
    plt.subplot(1,2,2), plt.imshow(im2), plt.title(tit2)
    plt.xticks([]), plt.yticks([])

# %%
plot_3img(im1, 'Image1', im1, 'Image2', (12,10))

# %%
def plot_3img(im1, tit1, im2, tit2, tam):
    figure(figsize = tam)
    plt.subplot(1,2,1), plt.imshow(im1, camp = 'gray'), plt.title(tit1)
    plt.xticks([]), plt.yticks([])
    plt.subplot(1,2,2), plt.imshow(im2, camp = 'gray'), plt.title(tit2)
    plt.xticks([]), plt.yticks([])

# %%
im1_ = im1[0:10500]

# %%
plt.imshow(im1_)

# %%
im1_ = im1[1200:1350, 2900:3100]

# %%
plt.imshow(im1_)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 plt.imshow(im1_)
#
# File D:\Salve_Aqui_Seus_Arquivos\Anaconda\envs\tads\Lib\site-packages\matplotlib\pyplot.py:3562, in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, data, **kwargs)
#    3541 @_copy_docstring_and_deprecators(Axes.imshow)
#    3542 def imshow(
#    3543     X: ArrayLike | PIL.Image.Image,
#    (...)
#    3560     **kwargs,
#    3561 ) -> AxesImage:
# -> 3562     __ret = gca().imshow(
#    3563         X,
#    3564         cmap=cmap,
#    3565         norm=norm,
#    3566         aspect=aspect,
#    3567         interpolation=interpolation,
#    3568         alpha=alpha,
#    3569         vmin=vmin,
#    3570         vmax=vmax,
#    3571         origin=origin,
#    3572         extent=extent,
#    3573         interpolation_stage=interpolation_stage,
#    3574         filternorm=filternorm,
#    3575         filterrad=filterrad,
#    3576         resample=resample,
#    3577         url=url,
#    3578         **({"data": data} if data is not None else {}),
#    3579         **kwargs,
#    3580     )
#    3581     sci(__ret)
#    3582     return __ret
#
# File D:\Salve_Aqui_Seus_Arquivos\Anaconda\envs\tads\Lib\site-packages\matplotlib\__init__.py:1486, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1483 @functools.wraps(func)
#    1484 def inner(ax, *args, data=None, **kwargs):
#    1485     if data is None:
# -> 1486         return func(
#    1487             ax,
#    1488             *map(sanitize_sequence, args),
#    1489             **{k: sanitize_sequence(v) for k, v in kwargs.items()})
#    1491     bound = new_sig.bind(ax, *args, **kwargs)
#    1492     auto_label = (bound.arguments.get(label_namer)
#    1493                   or bound.kwargs.get(label_namer))
#
# File D:\Salve_Aqui_Seus_Arquivos\Anaconda\envs\tads\Lib\site-packages\matplotlib\axes\_axes.py:5895, in Axes.imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, **kwargs)
#    5892 if aspect is not None:
#    5893     self.set_aspect(aspect)
# -> 5895 im.set_data(X)
#    5896 im.set_alpha(alpha)
#    5897 if im.get_clip_path() is None:
#    5898     # image does not already have clipping set, clip to Axes patch
#
# File D:\Salve_Aqui_Seus_Arquivos\Anaconda\envs\tads\Lib\site-packages\matplotlib\image.py:729, in _ImageBase.set_data(self, A)
#     727 if isinstance(A, PIL.Image.Image):
#     728     A = pil_to_array(A)  # Needed e.g. to apply png palette.
# --> 729 self._A = self._normalize_image_array(A)
#     730 self._imcache = None
#     731 self.stale = True
#
# File D:\Salve_Aqui_Seus_Arquivos\Anaconda\envs\tads\Lib\site-packages\matplotlib\image.py:704, in _ImageBase._normalize_image_array(A)
#     698 if A.ndim == 3:
#     699     # If the input data has values outside the valid range (after
#     700     # normalisation), we issue a warning and then clip X to the bounds
#     701     # - otherwise casting wraps extreme values, hiding outliers and
#     702     # making reliable interpretation impossible.
#     703     high = 255 if np.issubdtype(A.dtype, np.integer) else 1
# --> 704     if A.min() < 0 or high < A.max():
#     705         _log.warning(
#     706             'Clipping input data to the valid range for imshow with '
#     707             'RGB data ([0..1] for floats or [0..255] for integers). '
#     708             'Got range [%s..%s].',
#     709             A.min(), A.max()
#     710         )
#     711         A = np.clip(A, 0, high)
#
# File D:\Salve_Aqui_Seus_Arquivos\Anaconda\envs\tads\Lib\site-packages\numpy\ma\core.py:5833, in MaskedArray.min(self, axis, out, fill_value, keepdims)
#    5831 # No explicit output
#    5832 if out is None:
# -> 5833     result = self.filled(fill_value).min(
#    5834         axis=axis, out=out, **kwargs).view(type(self))
#    5835     if result.ndim:
#    5836         # Set the mask
#    5837         result.__setmask__(newmask)
#
# File D:\Salve_Aqui_Seus_Arquivos\Anaconda\envs\tads\Lib\site-packages\numpy\core\_methods.py:45, in _amin(a, axis, out, keepdims, initial, where)
#      43 def _amin(a, axis=None, out=None, keepdims=False,
#      44           initial=_NoValue, where=True):
# ---> 45     return umr_minimum(a, axis, None, out, keepdims, initial, where)
#
# ValueError: zero-size array to reduction operation minimum which has no identity

# %%
im1_ = im1[500:900, 2000:2500]

# %%
plt.imshow(im1_)

# %%
def plot_4img(im1, tit1, im2, tit2, im3, tit3, im4, tit4, tam):
    figure(figsize = tam)
    plt.subplot(1,4,1), plt.imshow(im1), plt.title(tit1)
    plt.xticks([]), plt.yticks([])
    plt.subplot(1,4,2), plt.imshow(im2), plt.title(tit2)
    plt.xticks([]), plt.yticks([])
    plt.subplot(1,4,3), plt.imshow(im3), plt.title(tit3)
    plt.xticks([]), plt.yticks([])
    plt.subplot(1,4,4), plt.imshow(im4), plt.title(tit4)
    plt.xticks([]), plt.yticks([])
    plt.show

# %%
im1_ = im1

# %%
plot_4img(im1, 'Image1', im1, 'Image2', im1, 'Image3', im1, 'Image4', (12,10))

# %%
im1_r = im1[:, :, 0]
im1_g = im1[:, :, 1]
im1_b = im1[:, :, 2]

# %%
plot_4img(im1, 'Original', im1_r, 'R', im1_g, 'G', im1_b, 'B', (12,10))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 plot_4img(im1, 'Original', im1_r, 'R', im1_g, 'G', im1_b, 'B', (12,10))
#
# NameError: name 'plot_4img' is not defined

# %%
import cv2

# %%
im_1cv = cv2.imread(path_img + 'cheetah.jpg')

# %%
im_1cv_rgb = cv2.cvtColor(im_1cv, cv2.COLOR_BGR2RGB)

# %%
HSV:
comprimento de onda 
Saturation
value = brilho
# Out:
#   Cell In[24], line 1
#     HSV:
#         ^
# SyntaxError: invalid syntax

# %%
im_1cv_hsv = cv2.cvtColor(im_1cv, cv2.COLOR_BGR2HSV)

# %%
im_1_h, im_1_s, im_1_v = cv2.split(im_1cv_hsv)

# %%
plot_4img(im1, 'Original', im_1_h, 'H', im_1_s, 'S', im_1_v, 'V', (12,10))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 plot_4img(im1, 'Original', im_1_h, 'H', im_1_s, 'S', im_1_v, 'V', (12,10))
#
# NameError: name 'plot_4img' is not defined

# %%
img = cv2.imread(path_img + 'OIP(7).jpeg')

# %%
def filtra_cor(img, cor, limiar = 30):
    cor_alvo_hsv = cv2.cvtColor(np.uint8([[cor]]), cv2.COLOR_BGR2HSV)[0][0]
    lim_inf = np.array([max(0, cor_alvo_hsv[0] - limiar), 50, 50])
    lim_sup = np.array([min(179, cor_alvo_hsv[0] + limiar), 225, 225])
    im_hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
    mask = cv2.inRange(im_hsv, lim_inf, lim-sup)
    return mask

# %%
lim_inf = np.array([130, 50, 0])
lim_sup = np.array([179, 255, 255])

# %%
mask = cv2.inRange(im_hsv, lim_inf, lim_sup)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 mask = cv2.inRange(im_hsv, lim_inf, lim_sup)
#
# NameError: name 'im_hsv' is not defined

# %%
cor = input('Escolha R, G ou B: ')
limiar = input('Informe o limiar entre 0 e 100: ')
if cor == 'R':
    alvo = (0, 0, 225)
elif cor == 'G':
    alvo = (0, 225, 0)
elif cor == 'B':
    alvo = (225, 0, 0)
else:
    print('Cor invalida')
filtro = filtra_cor(img, alvo, limiar)
resultado = cv2.bitwise_and(img, img, mask = filtro)
cv2.imshow('Original', img)
cv2.imshow('Cor filtro', resultado)
cv2.waitkey(0)
cv2.destroyAllWindows()

# %%
im = cv2.imread(path_img + 'arara2.jpg')
im_hsv = cv2.cvtColor(im, cv2.COLOR_BGR2HSV)
lim_inf = np.array([130, 50, 0])
lim_sup = np.array([179, 225, 225])
mask = cv2.inRange(im_hsv, lim_inf, lim_sup)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 im = cv2.imread(path_img + 'arara2.jpg')
#       2 im_hsv = cv2.cvtColor(im, cv2.COLOR_BGR2HSV)
#       3 lim_inf = np.array([130, 50, 0])
#
# NameError: name 'cv2' is not defined

# %%
resultado = cv2.bitwise_and(im, im, mask = mask)
cv2.imshow('Cor detalhada', np.hstack((im, resultado)))
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 resultado = cv2.bitwise_and(im, im, mask = mask)
#       2 cv2.imshow('Cor detalhada', np.hstack((im, resultado)))
#       3 cv2.waitKey(0)
#
# NameError: name 'cv2' is not defined
